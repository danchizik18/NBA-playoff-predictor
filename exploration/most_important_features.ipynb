# %% [markdown]
# # Here I find the most most important features for team success using EDA

# %% [markdown]
# # 1. Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nba_api.stats.endpoints import leaguegamefinder, teamdashboardbygeneralsplits, playercareerstats
from nba_api.stats.endpoints import leagueleaders
from nba_api.stats.static import teams, players
import seaborn as sns
import re

# %% [markdown]
# # 1. Loading in team season statistics, renaming teams, and only keeping numeric columns

# %%
team_stats = pd.read_csv('../data/team_stats_cleaned.csv')
team_stats.head(10)
team_stats.columns
# Out:
# Index(['group_set', 'group_value', 'season_year', 'gp', 'w', 'l', 'w_pct',
#        'min', 'fgm', 'fga', 'fg_pct', 'fg3m', 'fg3a', 'fg3_pct', 'ftm', 'fta',
#        'ft_pct', 'oreb', 'dreb', 'reb', 'ast', 'tov', 'stl', 'blk', 'blka',
#        'pf', 'pfd', 'pts', 'plus_minus', 'gp_rank', 'w_rank', 'l_rank',
#        'w_pct_rank', 'min_rank', 'fgm_rank', 'fga_rank', 'fg_pct_rank',
#        'fg3m_rank', 'fg3a_rank', 'fg3_pct_rank', 'ftm_rank', 'fta_rank',
#        'ft_pct_rank', 'oreb_rank', 'dreb_rank', 'reb_rank', 'ast_rank',
#        'tov_rank', 'stl_rank', 'blk_rank', 'blka_rank', 'pf_rank', 'pfd_rank',
#        'pts_rank', 'plus_minus_rank', 'team_name'],
#       dtype='object')

# %%
columns_to_keep = ['season_year', 'fgm', 'fga','fg3_pct', 'ftm', 'fta','ft_pct', 'oreb', 'dreb', 'reb', 'ast', 'tov', 'stl', 'blk', 'team_name']
team_stats = team_stats[columns_to_keep]
team_stats['fg%'] = team_stats['fgm']/team_stats['fga']
team_stats.head(10)
# Out:
#   season_year   fgm   fga  fg3_pct  ftm  fta  ft_pct  oreb  dreb   reb   ast  \
# 0     2024-25  1626  3498    0.354  707  901   0.785   456  1259  1715  1137
# 1     2024-25  1548  3358    0.366  615  776   0.793   406  1257  1663   945
# 2     2024-25  1673  3314    0.405  598  772   0.775   363  1252  1615  1087
# 3     2024-25  1507  3422    0.336  611  797   0.767   476  1145  1621   938
# 4     2024-25  1598  3411    0.372  554  696   0.796   345  1321  1666  1084
# 5     2024-25  1613  3359    0.375  692  892   0.776   426  1290  1716   954
# 6     2024-25  1623  3256    0.382  661  868   0.762   392  1234  1626  1130
# 7     2024-25  1523  3393    0.365  526  741   0.710   471  1252  1723  1063
# 8     2024-25  1542  3474    0.329  658  864   0.762   535  1270  1805   813
# 9     2024-25  1471  3173    0.363  626  803   0.780   397  1233  1630   895
#
#      tov  stl  blk              team_name       fg%
# 0  609.0  391  203          Atlanta Hawks  0.464837
# 1  440.0  285  208         Boston Celtics  0.460989
# 2  481.0  324  171    Cleveland Cavaliers  0.504828
# 3  569.0  364  206   New Orleans Pelicans  0.440386
# 4  560.0  280  173          Chicago Bulls  0.468484
# 5  545.0  308  224       Dallas Mavericks  0.480202
# 6  508.0  313  169         Denver Nuggets  0.498464
# 7  536.0  329  202  Golden State Warriors  0.448865
# 8  495.0  322  194        Houston Rockets  0.443869
# 9  610.0  359  166   Los Angeles Clippers  0.463599

# %%
team_stats = team_stats.sort_values('team_name')
team_stats.head(10)
# Out:
#    season_year   fgm   fga  fg3_pct  ftm  fta  ft_pct  oreb  dreb   reb   ast  \
# 0      2024-25  1626  3498    0.354  707  901   0.785   456  1259  1715  1137
# 1      2024-25  1548  3358    0.366  615  776   0.793   406  1257  1663   945
# 14     2024-25  1405  3135    0.366  628  776   0.809   344  1121  1465   931
# 29     2024-25  1337  3148    0.341  538  697   0.772   454  1164  1618   819
# 4      2024-25  1598  3411    0.372  554  696   0.796   345  1321  1666  1084
# 2      2024-25  1673  3314    0.405  598  772   0.775   363  1252  1615  1087
# 5      2024-25  1613  3359    0.375  692  892   0.776   426  1290  1716   954
# 6      2024-25  1623  3256    0.382  661  868   0.762   392  1234  1626  1130
# 28     2024-25  1578  3380    0.362  579  756   0.766   423  1276  1699   977
# 7      2024-25  1523  3393    0.365  526  741   0.710   471  1252  1723  1063
#
#       tov  stl  blk              team_name       fg%
# 0   609.0  391  203          Atlanta Hawks  0.464837
# 1   440.0  285  208         Boston Celtics  0.460989
# 14  576.0  271  135          Brooklyn Nets  0.448166
# 29  561.0  281  173      Charlotte Hornets  0.424714
# 4   560.0  280  173          Chicago Bulls  0.468484
# 2   481.0  324  171    Cleveland Cavaliers  0.504828
# 5   545.0  308  224       Dallas Mavericks  0.480202
# 6   508.0  313  169         Denver Nuggets  0.498464
# 28  602.0  279  195        Detroit Pistons  0.466864
# 7   536.0  329  202  Golden State Warriors  0.448865

# %%
nba_teams = [
    'ATL', 'BOS', 'BRO', 'CHA', 'CHI', 'CLE', 'DAL', 'DEN', 'DET', 'GSW', 
    'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NOP', 'NYK', 
    'OKC', 'ORL', 'PHI', 'PHX', 'POR', 'SAC', 'SAS', 'TOR', 'UTA', 'WAS'
]
nba_teams.sort()
nba_teams

team_stats['Team'] = nba_teams
team_stats
# Out:
#    season_year   fgm   fga  fg3_pct  ftm  fta  ft_pct  oreb  dreb   reb   ast  \
# 0      2024-25  1626  3498    0.354  707  901   0.785   456  1259  1715  1137
# 1      2024-25  1548  3358    0.366  615  776   0.793   406  1257  1663   945
# 14     2024-25  1405  3135    0.366  628  776   0.809   344  1121  1465   931
# 29     2024-25  1337  3148    0.341  538  697   0.772   454  1164  1618   819
# 4      2024-25  1598  3411    0.372  554  696   0.796   345  1321  1666  1084
# 2      2024-25  1673  3314    0.405  598  772   0.775   363  1252  1615  1087
# 5      2024-25  1613  3359    0.375  692  892   0.776   426  1290  1716   954
# 6      2024-25  1623  3256    0.382  661  868   0.762   392  1234  1626  1130
# 28     2024-25  1578  3380    0.362  579  756   0.766   423  1276  1699   977
# 7      2024-25  1523  3393    0.365  526  741   0.710   471  1252  1723  1063
# 8      2024-25  1542  3474    0.329  658  864   0.762   535  1270  1805   813
# 17     2024-25  1638  3347    0.374  632  810   0.780   340  1234  1574  1074
# 9      2024-25  1471  3173    0.363  626  803   0.780   397  1233  1630   895
# 10     2024-25  1458  3085    0.354  681  863   0.789   340  1150  1490   947
# 26     2024-25  1702  3526    0.368  736  952   0.773   488  1357  1845  1141
# 11     2024-25  1421  3125    0.366  646  827   0.781   345  1220  1565   937
# 12     2024-25  1447  3028    0.389  547  746   0.733   292  1243  1535   869
# 13     2024-25  1445  3170    0.377  583  745   0.783   377  1236  1613   915
# 3      2024-25  1507  3422    0.336  611  797   0.767   476  1145  1621   938
# 15     2024-25  1653  3330    0.378  637  796   0.800   389  1254  1643  1042
# 23     2024-25  1552  3307    0.351  562  689   0.816   360  1208  1568   937
# 16     2024-25  1477  3320    0.309  687  878   0.782   426  1198  1624   926
# 18     2024-25  1335  2986    0.340  661  850   0.778   356  1043  1399   766
# 19     2024-25  1446  3072    0.375  638  798   0.799   334  1199  1533   982
# 20     2024-25  1489  3305    0.340  586  759   0.772   460  1140  1600   859
# 21     2024-25  1587  3340    0.345  664  823   0.807   396  1237  1633   971
# 22     2024-25  1488  3286    0.342  634  797   0.795   411  1284  1695  1060
# 24     2024-25  1595  3419    0.345  597  800   0.746   462  1204  1666  1091
# 25     2024-25  1420  3100    0.365  654  821   0.797   432  1201  1633   889
# 27     2024-25  1414  3170    0.333  549  708   0.775   380  1172  1552   878
#
#       tov  stl  blk               team_name       fg% Team
# 0   609.0  391  203           Atlanta Hawks  0.464837  ATL
# 1   440.0  285  208          Boston Celtics  0.460989  BOS
# 14  576.0  271  135           Brooklyn Nets  0.448166  BRO
# 29  561.0  281  173       Charlotte Hornets  0.424714  CHA
# 4   560.0  280  173           Chicago Bulls  0.468484  CHI
# 2   481.0  324  171     Cleveland Cavaliers  0.504828  CLE
# 5   545.0  308  224        Dallas Mavericks  0.480202  DAL
# 6   508.0  313  169          Denver Nuggets  0.498464  DEN
# 28  602.0  279  195         Detroit Pistons  0.466864  DET
# 7   536.0  329  202   Golden State Warriors  0.448865  GSW
# 8   495.0  322  194         Houston Rockets  0.443869  HOU
# 17  528.0  307  192          Indiana Pacers  0.489393  IND
# 9   610.0  359  166    Los Angeles Clippers  0.463599  LAC
# 10  484.0  272  175      Los Angeles Lakers  0.472609  LAL
# 26  660.0  345  245       Memphis Grizzlies  0.482700  MEM
# 11  487.0  320  136              Miami Heat  0.454720  MIA
# 12  497.0  274  181         Milwaukee Bucks  0.477873  MIL
# 13  583.0  302  175  Minnesota Timberwolves  0.455836  MIN
# 3   569.0  364  206    New Orleans Pelicans  0.440386  NOP
# 15  501.0  290  152         New York Knicks  0.496396  NYK
# 23  428.0  421  214   Oklahoma City Thunder  0.469308  OKC
# 16  592.0  363  260           Orlando Magic  0.444880  ORL
# 18  494.0  339  152      Philadelphia 76ers  0.447086  PHI
# 19  506.0  273  185            Phoenix Suns  0.470703  PHX
# 20  607.0  300  208  Portland Trail Blazers  0.450530  POR
# 21  500.0  307  175        Sacramento Kings  0.475150  SAC
# 22  538.0  274  254       San Antonio Spurs  0.452830  SAS
# 24  621.0  299  170         Toronto Raptors  0.466511  TOR
# 25  660.0  252  181               Utah Jazz  0.458065  UTA
# 27  576.0  267  194      Washington Wizards  0.446057  WAS

# %% [markdown]
# # 2. Data cleaning and pre-processing

# %%
def clean_and_extract_team_id(team_name):
    cleaned_name = re.sub(r'\s\(\d+\)', '', team_name)
    team_id = cleaned_name[:3].upper()
    return team_id

relabeled_dict = {
    "Team": "Team1",
    "Team.1": "Team2",
    "W": "Team1wins",
    "W.1": "Team2wins"
}
playoff_results = pd.read_csv('../data/playoff_results.csv') 
playoff_results = playoff_results.rename(columns=relabeled_dict)
playoff_results['Team1'] = playoff_results['Team1'].apply(clean_and_extract_team_id)
playoff_results['Team2'] = playoff_results['Team2'].apply(clean_and_extract_team_id) 
playoff_results.replace('CHA', 'CHO', inplace=True)


team1_wins = playoff_results[['Yr', 'Team1', 'Team1wins']].rename(columns={'Team1': 'Team', 'Team1wins': 'wins'})
team2_wins = playoff_results[['Yr', 'Team2', 'Team2wins']].rename(columns={'Team2': 'Team', 'Team2wins': 'wins'})

combined_wins = pd.concat([team1_wins, team2_wins])

team_totals = combined_wins.groupby(['Yr', 'Team'], as_index=False)['wins'].sum()

team_totals_2024 = team_totals[team_totals['Yr'] == 2024]
print(team_totals_2024)
# Out:
#        Yr Team  wins
# 125  2024  BOS    16
# 126  2024  CLE     5
# 127  2024  DAL    13
# 128  2024  DEN     7
# 129  2024  IND     8
# 130  2024  LOS     3
# 131  2024  MIA     1
# 132  2024  MIL     2
# 133  2024  MIN     9
# 134  2024  NEW     7
# 135  2024  OKL     6
# 136  2024  ORL     3
# 137  2024  PHI     2
# 138  2024  PHO     0

# %%
team_stats = team_stats.rename(columns = {"season_year": "Yr", "team_name":"Team"})
team_stats.head()
# Out:
#          Yr   fgm   fga  fg3_pct  ftm  fta  ft_pct  oreb  dreb   reb   ast  \
# 0   2024-25  1626  3498    0.354  707  901   0.785   456  1259  1715  1137
# 1   2024-25  1548  3358    0.366  615  776   0.793   406  1257  1663   945
# 14  2024-25  1405  3135    0.366  628  776   0.809   344  1121  1465   931
# 29  2024-25  1337  3148    0.341  538  697   0.772   454  1164  1618   819
# 4   2024-25  1598  3411    0.372  554  696   0.796   345  1321  1666  1084
#
#       tov  stl  blk               Team       fg% Team
# 0   609.0  391  203      Atlanta Hawks  0.464837  ATL
# 1   440.0  285  208     Boston Celtics  0.460989  BOS
# 14  576.0  271  135      Brooklyn Nets  0.448166  BRO
# 29  561.0  281  173  Charlotte Hornets  0.424714  CHA
# 4   560.0  280  173      Chicago Bulls  0.468484  CHI

# %%
print(team_stats.columns)
print(team_totals_2024.columns)
# Out:
# Index(['Yr', 'fgm', 'fga', 'fg3_pct', 'ftm', 'fta', 'ft_pct', 'oreb', 'dreb',
#        'reb', 'ast', 'tov', 'stl', 'blk', 'fg%'],
#       dtype='object')
# Index(['Yr', 'Team', 'wins'], dtype='object')

# %%
team_stats = team_stats.drop(columns=['Team'])

# %%
ranked_data = merged_data.copy()
numeric_cols = ['fgm', 'fga', 'fg3_pct', 'ftm', 'fta', 'ft_pct', 'oreb', 'dreb', 'reb', 
                'ast', 'tov', 'stl', 'blk', 'fg%'] 

for col in numeric_cols:
    ranked_data[f'{col}_rank'] = ranked_data[col].rank(ascending=False)  

ranked_data = ranked_data[['Yr', 'Team', 'wins'] + [f'{col}_rank' for col in numeric_cols]]
ranked_data.head()
# Out:
#       Yr Team  wins  fgm_rank  fga_rank  fg3_pct_rank  ftm_rank  fta_rank  \
# 1   2024  BOS  16.0       5.0       2.0           7.5       7.0       7.0
# 5   2024  CLE   5.0       1.0       5.0           1.0       8.0       8.0
# 6   2024  DAL  13.0       4.0       1.0           5.0       1.0       1.0
# 7   2024  DEN   7.0       3.0       6.0           3.0       3.5       3.0
# 11  2024  IND   8.0       2.0       3.0           6.0       6.0       6.0
#
#     ft_pct_rank  oreb_rank  dreb_rank  reb_rank  ast_rank  tov_rank  stl_rank  \
# 1           1.0        3.0        2.0       2.0       5.0      10.0       9.0
# 5           8.0        6.0        3.0       5.0       2.0       9.0       3.0
# 6           7.0        1.5        1.0       1.0       4.0       3.0       6.0
# 7           9.0        4.0        6.5       3.0       1.0       5.0       5.0
# 11          5.0        9.0        6.5       7.0       3.0       4.0       7.0
#
#     blk_rank  fg%_rank
# 1        3.0       6.0
# 5        7.0       1.0
# 6        2.0       4.0
# 7        8.0       2.0
# 11       4.0       3.0

# %% [markdown]
# # 3. Quick histogram plotting using matplotlib to see what's going on

# %%
for col in numeric_cols:
    plt.figure(figsize=(8, 6))
    plt.scatter(ranked_data[f'{col}_rank'], ranked_data['wins'], alpha=0.7, edgecolor='k')
    plt.title(f'Wins vs {col.capitalize()} Rank', fontsize=14)
    plt.xlabel(f'{col.capitalize()} Rank (Lower is Better)', fontsize=12)
    plt.ylabel('Wins', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()

# %% [markdown]
# # 4. Finding correlation between each feature and # of wins

# %%
correlation_results = []

for col in numeric_cols:
    rank_col = f"{col}_rank"  
    if rank_col in ranked_data.columns:  
        correlation = abs(ranked_data[rank_col].corr(ranked_data['wins']))
        correlation_results.append({'Metric': rank_col, 'Correlation with Playoff Wins': correlation})
    else:
        correlation_results.append({'Metric': rank_col, 'Correlation with Wins': 'N/A'})

correlation_table = pd.DataFrame(correlation_results)

correlation_table_sorted = correlation_table.sort_values('Correlation with Playoff Wins', ascending = False)
print(correlation_table_sorted)
# Out:
#           Metric  Correlation with Playoff Wins
# 1       fga_rank                       0.775605
# 8       reb_rank                       0.760971
# 7      dreb_rank                       0.715582
# 6      oreb_rank                       0.543108
# 12      blk_rank                       0.519509
# 11      stl_rank                       0.497558
# 0       fgm_rank                       0.409754
# 9       ast_rank                       0.387803
# 5    ft_pct_rank                       0.365851
# 13      fg%_rank                       0.314632
# 2   fg3_pct_rank                       0.062384
# 3       ftm_rank                       0.047705
# 10      tov_rank                       0.021951
# 4       fta_rank                       0.014634

# %% [markdown]
# # Result: Most important features --> fga_rank, reb_rank, dreb_rank, oreb_rank, and blk_rank
